# %% [markdown]
# # Loading the book

# %%
with open("miracle_in_the_andes.txt", 'r', encoding='utf-8') as file:
    book = file.read()

# %% [markdown]
# # Most used non stop words (non-articles)

# %%
import regex as re

# %%
pattern = re.compile("[a-zA-Z]+")
findings = re.findall(pattern, book.lower()) 
len(findings)
# Out:
# 86798

# %%
d= {}
for word in findings:
    if word in d.keys():
        d[word] = d[word] + 1
    else:
        d[word] = 1

# %%
d_list = [(value, key) for (key, value) in d.items()]
d_list = sorted(d_list, reverse=True)

# %%
import nltk

# Download the stopwords resource first
nltk.download('stopwords')

# Now you can use the stopwords
from nltk.corpus import stopwords
english_stopwords = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dhruv\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
filtered_words = []
for count , word in d_list:
    if word not in english_stopwords:
        filtered_words.append((word, count))

# %%
filtered_words
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 filtered_words.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %% [markdown]
# # Sentiment Analysis: Postive and negatices chapter

# %% [markdown]
# ## Example

# %%
# First, import nltk and download the required resource
import nltk
nltk.download('vader_lexicon')

# Now import and use the SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\dhruv\AppData\Roaming\nltk_data...

# %%
analyzer = SentimentIntensityAnalyzer()
analyzer.polarity_scores("Help your self")
# Out:
# {'neg': 0.0, 'neu': 0.426, 'pos': 0.574, 'compound': 0.4019}

# %%
analyzer.polarity_scores(book)
# Out:
# {'neg': 0.116, 'neu': 0.76, 'pos': 0.125, 'compound': 1.0}

# %% [markdown]
# ## Per Chapter

# %%
pattern = re.compile("Chapter [0-9]+")
chapters = re.split(pattern, book)

# %%
chapters = chapters[1:]

# %%
for chapter in chapters:
    scores = analyzer.polarity_scores(chapter)
    negative = scores['neg']  
    netural = scores['neu']    
    postive = scores['pos']     
    compund = scores['compound'] 

    if sc
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 for chapter in chapters:
#       2     scores = analyzer.polarity_scores(chapter)
# ----> 3     negative = scores('neg')
#       4     netural = scores('neu')
#       5     postive = scores('pos')
#
# TypeError: 'dict' object is not callable
